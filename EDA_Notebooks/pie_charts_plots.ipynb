# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
mylabels = ["Web Scraping", "Feature Set Generation", "Modeling"]
times = [600, 12, 362.5]
mycolors = ["orange", "green", 'blue']


plt.pie(times, labels = mylabels, colors = mycolors, shadow=True)
plt.title('Pipelines share of time in the workflow')
plt.savefig('1_pie_chart.png')
plt.show()

# %%
mylabels = ["College Data Web Scraping", "NBA Data Web Scraping", "Preprocessed Feature Set Generation", "Feature Set Imputation", "Hyperparameter Tuning",
            "Model Training", "Model Prediction", "Model Evaluation"]
times = [540, 60, 10, 2, 360, 1, 0.5, 1]

df = pd.DataFrame()
#df['label'] = mylabels
#df['values'] = times
##df['values'].plot(kind = 'pie', labels = [])
labels = ['', '', '', '', '', '', '', '']
plt.plot()
plt.pie(times, labels = labels, shadow=True)
plt.title('Step functions share of time in the workflow')
plt.legend(labels = mylabels, bbox_to_anchor=(0, 0.75))
plt.savefig('2_pie_chart.png', bbox_inches='tight')
plt.show()
